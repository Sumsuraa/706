# %%
# !pip install pandas
# !pip install scikit-learn
# !pip install torch
# !pip install torchtext
# Out:
# Collecting kaggle
#   Using cached kaggle-1.6.14-py3-none-any.whl
# Requirement already satisfied: six>=1.10 in c:\new folder (6)\myenv\lib\site-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi>=2023.7.22 in c:\new folder (6)\myenv\lib\site-packages (from kaggle) (2024.2.2)
# Requirement already satisfied: python-dateutil in c:\new folder (6)\myenv\lib\site-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: requests in c:\new folder (6)\myenv\lib\site-packages (from kaggle) (2.32.1)
# Collecting tqdm (from kaggle)
#   Using cached tqdm-4.66.4-py3-none-any.whl.metadata (57 kB)
# Collecting python-slugify (from kaggle)
#   Using cached python_slugify-8.0.4-py2.py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: urllib3 in c:\new folder (6)\myenv\lib\site-packages (from kaggle) (2.2.1)
# Requirement already satisfied: bleach in c:\new folder (6)\myenv\lib\site-packages (from kaggle) (6.1.0)
# Requirement already satisfied: webencodings in c:\new folder (6)\myenv\lib\site-packages (from bleach->kaggle) (0.5.1)
# Collecting text-unidecode>=1.3 (from python-slugify->kaggle)
#   Using cached text_unidecode-1.3-py2.py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\new folder (6)\myenv\lib\site-packages (from requests->kaggle) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\new folder (6)\myenv\lib\site-packages (from requests->kaggle) (3.7)
# Requirement already satisfied: colorama in c:\new folder (6)\myenv\lib\site-packages (from tqdm->kaggle) (0.4.6)
# Using cached python_slugify-8.0.4-py2.py3-none-any.whl (10 kB)
# Using cached tqdm-4.66.4-py3-none-any.whl (78 kB)
# Using cached text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
# Installing collected packages: text-unidecode, tqdm, python-slugify, kaggle
# Successfully installed kaggle-1.6.14 python-slugify-8.0.4 text-unidecode-1.3 tqdm-4.66.4
# Collecting pandas
#   Using cached pandas-2.2.2-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Collecting numpy>=1.23.2 (from pandas)
#   Using cached numpy-1.26.4-cp311-cp311-win_amd64.whl.metadata (61 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\new folder (6)\myenv\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\new folder (6)\myenv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Using cached pandas-2.2.2-cp311-cp311-win_amd64.whl (11.6 MB)
# Using cached numpy-1.26.4-cp311-cp311-win_amd64.whl (15.8 MB)
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Installing collected packages: pytz, tzdata, numpy, pandas
# Successfully installed numpy-1.26.4 pandas-2.2.2 pytz-2024.1 tzdata-2024.1
# Collecting scikit-learn
#   Using cached scikit_learn-1.4.2-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.19.5 in c:\new folder (6)\myenv\lib\site-packages (from scikit-learn) (1.26.4)
# Collecting scipy>=1.6.0 (from scikit-learn)
#   Using cached scipy-1.13.0-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn)
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Using cached scikit_learn-1.4.2-cp311-cp311-win_amd64.whl (10.6 MB)
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Using cached scipy-1.13.0-cp311-cp311-win_amd64.whl (46.2 MB)
# Using cached threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.4.2 scikit-learn-1.4.2 scipy-1.13.0 threadpoolctl-3.5.0
# Collecting torch
#   Using cached torch-2.3.0-cp311-cp311-win_amd64.whl.metadata (26 kB)
# Collecting torchvision
#   Using cached torchvision-0.18.0-cp311-cp311-win_amd64.whl.metadata (6.6 kB)
# Collecting filelock (from torch)
#   Using cached filelock-3.14.0-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\new folder (6)\myenv\lib\site-packages (from torch) (4.11.0)
# Collecting sympy (from torch)
#   Using cached sympy-1.12-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch)
#   Using cached networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: jinja2 in c:\new folder (6)\myenv\lib\site-packages (from torch) (3.1.4)
# Collecting fsspec (from torch)
#   Using cached fsspec-2024.5.0-py3-none-any.whl.metadata (11 kB)
# Collecting mkl<=2021.4.0,>=2021.1.1 (from torch)
#   Using cached mkl-2021.4.0-py2.py3-none-win_amd64.whl.metadata (1.4 kB)
# Requirement already satisfied: numpy in c:\new folder (6)\myenv\lib\site-packages (from torchvision) (1.26.4)
# Collecting pillow!=8.3.*,>=5.3.0 (from torchvision)
#   Using cached pillow-10.3.0-cp311-cp311-win_amd64.whl.metadata (9.4 kB)
# Collecting intel-openmp==2021.* (from mkl<=2021.4.0,>=2021.1.1->torch)
#   Using cached intel_openmp-2021.4.0-py2.py3-none-win_amd64.whl.metadata (1.2 kB)
# Collecting tbb==2021.* (from mkl<=2021.4.0,>=2021.1.1->torch)
#   Using cached tbb-2021.12.0-py3-none-win_amd64.whl.metadata (1.1 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\new folder (6)\myenv\lib\site-packages (from jinja2->torch) (2.1.5)
# Collecting mpmath>=0.19 (from sympy->torch)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Using cached torch-2.3.0-cp311-cp311-win_amd64.whl (159.8 MB)
# Using cached torchvision-0.18.0-cp311-cp311-win_amd64.whl (1.2 MB)
# Using cached mkl-2021.4.0-py2.py3-none-win_amd64.whl (228.5 MB)
# Using cached intel_openmp-2021.4.0-py2.py3-none-win_amd64.whl (3.5 MB)
# Using cached tbb-2021.12.0-py3-none-win_amd64.whl (286 kB)
# Using cached pillow-10.3.0-cp311-cp311-win_amd64.whl (2.5 MB)
# Using cached filelock-3.14.0-py3-none-any.whl (12 kB)
# Using cached fsspec-2024.5.0-py3-none-any.whl (316 kB)
# Using cached networkx-3.3-py3-none-any.whl (1.7 MB)
# Using cached sympy-1.12-py3-none-any.whl (5.7 MB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Installing collected packages: tbb, mpmath, intel-openmp, sympy, pillow, networkx, mkl, fsspec, filelock, torch, torchvision
# Successfully installed filelock-3.14.0 fsspec-2024.5.0 intel-openmp-2021.4.0 mkl-2021.4.0 mpmath-1.3.0 networkx-3.3 pillow-10.3.0 sympy-1.12 tbb-2021.12.0 torch-2.3.0 torchvision-0.18.0
# Collecting torchtext
#   Using cached torchtext-0.18.0-cp311-cp311-win_amd64.whl.metadata (7.9 kB)
# Requirement already satisfied: tqdm in c:\new folder (6)\myenv\lib\site-packages (from torchtext) (4.66.4)
# Requirement already satisfied: requests in c:\new folder (6)\myenv\lib\site-packages (from torchtext) (2.32.1)
# Requirement already satisfied: torch>=2.3.0 in c:\new folder (6)\myenv\lib\site-packages (from torchtext) (2.3.0)
# Requirement already satisfied: numpy in c:\new folder (6)\myenv\lib\site-packages (from torchtext) (1.26.4)
# Requirement already satisfied: filelock in c:\new folder (6)\myenv\lib\site-packages (from torch>=2.3.0->torchtext) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\new folder (6)\myenv\lib\site-packages (from torch>=2.3.0->torchtext) (4.11.0)
# Requirement already satisfied: sympy in c:\new folder (6)\myenv\lib\site-packages (from torch>=2.3.0->torchtext) (1.12)
# Requirement already satisfied: networkx in c:\new folder (6)\myenv\lib\site-packages (from torch>=2.3.0->torchtext) (3.3)
# Requirement already satisfied: jinja2 in c:\new folder (6)\myenv\lib\site-packages (from torch>=2.3.0->torchtext) (3.1.4)
# Requirement already satisfied: fsspec in c:\new folder (6)\myenv\lib\site-packages (from torch>=2.3.0->torchtext) (2024.5.0)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\new folder (6)\myenv\lib\site-packages (from torch>=2.3.0->torchtext) (2021.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\new folder (6)\myenv\lib\site-packages (from requests->torchtext) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\new folder (6)\myenv\lib\site-packages (from requests->torchtext) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\new folder (6)\myenv\lib\site-packages (from requests->torchtext) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\new folder (6)\myenv\lib\site-packages (from requests->torchtext) (2024.2.2)
# Requirement already satisfied: colorama in c:\new folder (6)\myenv\lib\site-packages (from tqdm->torchtext) (0.4.6)
# Requirement already satisfied: intel-openmp==2021.* in c:\new folder (6)\myenv\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=2.3.0->torchtext) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\new folder (6)\myenv\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=2.3.0->torchtext) (2021.12.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\new folder (6)\myenv\lib\site-packages (from jinja2->torch>=2.3.0->torchtext) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in c:\new folder (6)\myenv\lib\site-packages (from sympy->torch>=2.3.0->torchtext) (1.3.0)
# Using cached torchtext-0.18.0-cp311-cp311-win_amd64.whl (1.9 MB)
# Installing collected packages: torchtext
# Successfully installed torchtext-0.18.0

# %%
import pandas as pd
import numpy as np
import sklearn
import torch
import torchtext

# Get versions of installed packages
versions = {
    "pandas": pd.__version__,
    "numpy": np.__version__,
    "scikit-learn": sklearn.__version__,
    "torch": torch.__version__,
    "torchtext": torchtext.__version__
}

for package, version in versions.items():
    print(f"{package}=={version}")
# Out:
# pandas==2.2.2
# numpy==1.26.4
# scikit-learn==1.4.2
# torch==2.3.0+cpu
# torchtext==0.18.0+cpu
